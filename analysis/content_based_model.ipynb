# %%
import pandas as pd
import numpy as np
import heapq

# %%
rmd_user = pd.read_csv('user_based_rmd.csv')
content_based_data = pd.read_csv('data_final/combined_csv.csv')

# %%
rmd_user.head()
# Out:
#                 game_name        recommend1          recommend2  \
# 0            A Bird Story    State of Decay           Ys Origin
# 1  A Story About My Uncle          Unturned  Grand Theft Auto V
# 2    AdVenture Capitalist         Dark Void              Gothic
# 3   Age of Empires Online  And Yet It Moves               Braid
# 4          Age of Wonders         Gone Home              Portal
#
#          recommend3         recommend4             recommend5     recommend6  \
# 0     Saints Row IV         BioShock 2        Game Dev Tycoon       Terraria
# 1       Tomb Raider        Garry's Mod               Warframe     Thief Gold
# 2          Gothic 3                MDK           PlanetSide 2    Singularity
# 3  Grand Theft Auto  Street Fighter IV  Team Fortress Classic       Unturned
# 4       Machinarium          Max Payne               Portal 2  Borderlands 2
#
#           recommend7         recommend8          recommend9  \
# 0     Alpha Protocol      Emily is Away       Hotline Miami
# 1  BioShock Infinite         Metro 2033          Quake Live
# 2           The Room     Tomb Raider II             Enclave
# 3             Arma 3  Fable Anniversary     Team Fortress 2
# 4  Crusader Kings II        Garry's Mod  Grand Theft Auto V
#
#            recommend10
# 0         Rogue Legacy
# 1        Rocket League
# 2           Thief Gold
# 3  Grand Theft Auto IV
# 4          Half-Life 2

# %%
content_based_data.head()
# Out:
#    difficulty  length                        name  rating platform  sales  \
# 0        2.93   44.84               Mass Effect 2    4.33       pc   1000
# 1        3.15   17.52  The Curse of Monkey Island    4.32       pc    200
# 2        3.12   35.22      Half-Life 1: Anthology    4.32       pc    100
# 3        3.24   60.04   Warcraft III: Battlechest    4.32       pc    200
# 4        2.46   46.86                 Steins;Gate    4.32       pc    200
#
#            type1 type2  Unnamed: 0
# 0   role-playing  None         NaN
# 1      adventure  None         NaN
# 2  miscellaneous  None         NaN
# 3       strategy  None         NaN
# 4      adventure  None         NaN

# %%
# choose all games in content table
big_game_list = content_based_data['name'].to_list()
print(len(big_game_list))

# remove duplicates
big_game_list = list(set(big_game_list))
print(len(big_game_list))
# Out:
# 3092
# 2378

# %%
small_game_list = rmd_user['game_name'].to_list()
len(small_game_list)
# Out:
# 458

# %%
# content based recommendation algorithm only works on items that not included in user based algorithm
aimed_list = []
for i in range(len(big_game_list)):
    if (big_game_list[i] not in small_game_list):
        aimed_list.append(big_game_list[i])
print(len(aimed_list))
# Out:
# 1921

# %%
# find range of different parameters
print(content_based_data['difficulty'].min(),content_based_data['difficulty'].max())
print(content_based_data['length'].min(),content_based_data['length'].max())
print(content_based_data['rating'].min(),content_based_data['rating'].max())
# Out:
# 1.16 4.79
# 0.76 80.0
# 1.21 4.56

# %%
# This function calculates square of distance between two points
def cal_dist(a,b):
    sum = 0
    for i in range(len(a)):
        sum += (a[i]-b[i])**2
    return np.sqrt(sum)

# we create new normalized difficulty and length in range [0,1]
# formula to normalize norm_val = (X-Xmin)/(Xmax-Xmin)
# append list contains [name,norm_difficulty,norm_length]
norm_list = []
content_based_data.head()
for i in range(len(content_based_data)):
    name = content_based_data.iloc[i][2]
    difficulty = content_based_data.iloc[i][0]
    length = content_based_data.iloc[i][1]
    rating = content_based_data.iloc[i][3]
    norm_difficulty = (difficulty-content_based_data['difficulty'].min())/(content_based_data['difficulty'].max()-content_based_data['difficulty'].min())
    norm_length = (length-content_based_data['length'].min())/(content_based_data['length'].max()-content_based_data['length'].min())
    norm_rating = (rating-content_based_data['rating'].min())/(content_based_data['rating'].max()-content_based_data['rating'].min())
    temp = [name,round(norm_difficulty,2),round(norm_length,2),round(norm_rating,2),content_based_data.iloc[i][5],content_based_data.iloc[i][4]]
    norm_list.append(temp)

norm_list[:5]
# Out:
# [['Mass Effect 2', 0.49, 0.56, 0.93, 1000, 'pc'],
#  ['The Curse of Monkey Island', 0.55, 0.21, 0.93, 200, 'pc'],
#  ['Half-Life 1: Anthology', 0.54, 0.43, 0.93, 100, 'pc'],
#  ['Warcraft III: Battlechest', 0.57, 0.75, 0.93, 200, 'pc'],
#  ['Steins;Gate', 0.36, 0.58, 0.93, 200, 'pc']]

# %%
dist_dic = {}
sale_volume_bonus_dic = { 100:0, 200:0.02, 500:0.05, 1000:0.1 }

for i in range(len(norm_list)):
    key = norm_list[i][0]
    dist_list = []
    for j in range(len(norm_list)):
        # check only recommends games in the same platform and not the same name
        if (norm_list[i][0] == norm_list[j][0] or norm_list[i][5] != norm_list[j][5]):
            continue
        temp_dist = cal_dist([norm_list[i][1],norm_list[i][2]],[norm_list[j][1],norm_list[j][2]])
        # give some bonus if the game has high rating or high sale volume
        temp_dist -= sale_volume_bonus_dic[norm_list[i][4]]
        temp_dist -= norm_list[i][3]*0.1  # bonus range for rating is [0,0.1]
        dist_list.append((norm_list[j][0],temp_dist))
    dist_list.sort(key = lambda x:x[1])
    dist_dic[key] = dist_list

# %%
# example output
dist_dic['The Legend of Zelda: Breath of the Wild']
# Out:
# [('The Witcher 3: Wild Hunt - Complete Edition', -0.16999999999999998),
#  ("Dragon's Dogma: Dark Arisen", -0.14999999999999997),
#  ('Octopath Traveler', -0.14169048105154697),
#  ('Super Smash Bros. Ultimate', -0.11455996254682473),
#  ('Disgaea 5 Complete', -0.11000000000000004),
#  ('Xenoblade Chronicles 2', -0.11000000000000004),
#  ('Hyrule Warriors: Definitive Edition', -0.10566018867943398),
#  ('Shin Megami Tensei V', -0.10100505063388343),
#  ('The Elder Scrolls V: Skyrim', -0.10000000000000003),
#  ('Xenoblade Chronicles: Definitive Edition', -0.09000000000000002),
#  ('Final Fantasy XII: The Zodiac Age', -0.08819660112501053),
#  ('Final Fantasy X / X-2 HD Remaster', -0.08819660112501053),
#  ('Bravely Default II', -0.08819660112501053),
#  ('Yu-Gi-Oh! Legacy of the Duelist: Link Evolution', -0.08819660112501053),
#  ('Fire Emblem: Three Houses', -0.08000000000000002),
#  ('Digimon Story Cyber Sleuth: Complete Edition', -0.08000000000000002),
#  ('Monster Hunter Generations Ultimate', -0.08000000000000002),
#  ('Monster Hunter Rise', -0.07916954026405429),
#  ('Monster Hunter Stories 2: Wings of Ruin', -0.07350889359326482),
#  ('Tales of Vesperia: Definitive Edition', -0.07193751525134309),
#  ('Dragon Quest XI S: Echoes of an Elusive Age - Definitive Edition', -0.07),
#  ('Ring Fit Adventure', -0.060716117228158784),
#  ('Rune Factory 4 Special', -0.06),
#  ('Super Dragon Ball Heroes: World Mission', -0.05133931252681498),
#  ('Rune Factory 5', -0.04867254049578443),
#  ('Diablo III: Eternal Collection', -0.04188611699158107),
#  ('Fortnite', -0.032369453857597846),
#  ('Dragon Quest Builders 2', -0.020000000000000018),
#  ('Collection of Mana', -0.017517124091053354),
#  ('Story of Seasons: Friends of Mineral Town', -0.015609110854142266),
#  ('Triangle Strategy', -0.010263340389897235),
#  ('Disgaea 6: Defiance of Destiny', -0.008950268254572014),
#  ('Splatoon 2', -0.0027691707668398013),
#  ('Stardew Valley', 0.0009975124224178011),
#  ('Minecraft', 0.011896201004170909),
#  ('Dragon Quest Builders', 0.012602916254693008),
#  ('Ys VIII: Lacrimosa of DANA', 0.032594066992260085),
#  ('Dragon Ball: Xenoverse 2', 0.033452350598575015),
#  ('Valkyria Chronicles 4', 0.041867732448956474),
#  ('Grandia HD Collection', 0.04839484696748439),
#  ('Story of Seasons: Pioneers of Olive Town', 0.04999999999999996),
#  ('Hyrule Warriors: Age of Calamity', 0.05495097567963919),
#  ('Pokemon Legends: Arceus', 0.055538646783612755),
#  ('Super Mario Maker 2', 0.06),
#  ('Ni no Kuni: Wrath of the White Witch', 0.06172504656604799),
#  ('Mega Man Legacy Collection + Mega Man Legacy Collection 2',
#   0.06683328128252664),
#  ('Final Fantasy VIII Remastered', 0.07313000567495326),
#  ('Mega Man X Legacy Collection 1 + 2', 0.0745906043549196),
#  ('The Binding of Isaac: Afterbirth +', 0.07658633371878665),
#  ('Super Mario 3D All-Stars', 0.09410882339705484),
#  ('Fire Emblem Warriors', 0.10016662039607271),
#  ('Final Fantasy IX', 0.10675723300355938),
#  ('Shining Resonance Refrain', 0.10805843601498727),
#  ('Dark Souls Remastered', 0.1182766092567909),
#  ('The World Ends with You: Final Remix', 0.14014702703389892),
#  ('Atelier Ryza: Ever Darkness &amp; the Secret Hideout', 0.14014702703389903),
#  ('The Great Ace Attorney Chronicles', 0.14014702703389903),
#  ('Final Fantasy VII', 0.14176014981270119),
#  ('Pokemon Mystery Dungeon: Rescue Team DX', 0.14481879299133327),
#  ('Wargroove', 0.1569313659514949),
#  ('Pokemon Shining Pearl', 0.16619666847201106),
#  ('Fate/Extella: The Umbral Star', 0.17),
#  ('Tokyo Mirage Sessions #FE Encore', 0.17),
#  ('Shin Megami Tensei III: Nocturne HD Remaster', 0.17054014627297806),
#  ('Immortals Fenyx Rising', 0.1710795063055894),
#  ('Mega Man X Legacy Collection', 0.1733630940518894),
#  ('Mario Kart 8 Deluxe', 0.1733630940518894),
#  ('NEO: The World Ends With You', 0.1736308338453881),
#  ('Enter the Gungeon', 0.17483329627982622),
#  ('Pokemon Brilliant Diamond', 0.17802116342871596),
#  ('Daemon X Machina', 0.17947331922020546),
#  ('Phoenix Wright: Ace Attorney Trilogy', 0.17947331922020546),
#  ('Hollow Knight', 0.18483762809787715),
#  ('Hades', 0.19560080889704964),
#  ('Rocket League', 0.20012498047485114),
#  ('Animal Crossing: New Horizons', 0.21000000000000005),
#  ('Miitopia', 0.21436698710201327),
#  ('Mega Man Zero / ZX Legacy Collection', 0.22296571965113207),
#  ('Persona 5 Strikers', 0.23566041821583936),
#  ('Okami HD', 0.24283179650969064),
#  ('BlazBlue: Cross Tag Battle', 0.24384682042344294),
#  ('Puyo Puyo Tetris', 0.2455333881989092),
#  ('Mario Party Superstars', 0.2492215489043241),
#  ('Marvel Ultimate Alliance 3: The Black Order', 0.25011109739707593),
#  ('The Legend of Zelda: Skyward Sword HD', 0.2512205669071391),
#  ('Bayonetta + Bayonetta 2', 0.2539823785126466),
#  ('Super Mario Odyssey', 0.268187996428785),
#  ('Starlink: Battle for Atlas', 0.2767598976424087),
#  ('Trials of Mana', 0.29040799340956913),
#  ('Pokemon UNITE', 0.29040799340956913),
#  ('LEGO Marvel Super Heroes 2', 0.2924428900898053),
#  ('Crash Bandicoot N. Sane Trilogy', 0.2972926703662543),
#  ('Tetris 99', 0.3000999900019995),
#  ('Super Mario Bros. 35', 0.30159744815937817),
#  ('Pokken Tournament DX', 0.3063595560468866),
#  ('Dragon Ball FighterZ', 0.30803543183522153),
#  ('Mario + Rabbids: Kingdom Battle', 0.32239831546435915),
#  ('Crash Team Racing: Nitro-Fueled', 0.33150729063673257),
#  ('Spyro Reignited Trilogy', 0.3412023651093924),
#  ('Fast RMX', 0.3434151267677411),
#  ('Pokemon Shield', 0.3448853090330112),
#  ('Mortal Kombat 11', 0.3503635162326806),
#  ('Astral Chain', 0.3514526271584896),
#  ('Castlevania Anniversary Collection', 0.35317266743757336),
#  ('Dead Cells', 0.3554277630799527),
#  ('I Am Setsuna', 0.3554277630799527),
#  ('ARMS', 0.3614267539047281),
#  ('Rayman Legends: Definitive Edition', 0.36222771187482394),
#  ('Pokemon Quest', 0.3636488268416781),
#  ('Street Fighter: 30th Anniversary Collection', 0.3742821606144493),
#  ('Bloodstained: Ritual of the Night', 0.37870545184921156),
#  ('Paper Mario: The Origami King', 0.38240879114244153),
#  ('Clubhouse Games: 51 Worldwide Classics', 0.3846366392897388),
#  ('LEGO City Undercover', 0.3860034129593445),
#  ('Super Kirby Clash', 0.39033888572581776),
#  ('South Park: The Fractured But Whole', 0.40083275543199215),
#  ('Shovel Knight: Treasure Trove', 0.40827625302982196),
#  ('Mario Golf: Super Rush', 0.420966987850401),
#  ("Pokemon: Let's Go, Eevee!", 0.4262587324740471),
#  ('Pokemon Sword', 0.43780874876407905),
#  ('Yooka-Laylee', 0.44498061986388404),
#  ('Super Mario Party', 0.44845971347493907),
#  ('Donkey Kong Country: Tropical Freeze', 0.4576473218982954),
#  ("Pokemon: Let's Go, Pikachu!", 0.4603029607687672),
#  ('Ultra Street Fighter II: The Final Challengers', 0.46370174024180466),
#  ('New Pokemon Snap', 0.4640783086353597),
#  ("Super Mario 3D World + Bowser's Fury", 0.47082039324993685),
#  ('Mario Tennis Aces', 0.4726812023536855),
#  ('DOOM', 0.48),
#  ('Pikmin 3 Deluxe', 0.4905070600652828),
#  ('Monster Boy and the Cursed Kingdom', 0.49065186599328026),
#  ('Bayonetta', 0.5003570517957251),
#  ('Bayonetta 2', 0.50178344238091),
#  ('New Super Mario Bros. U Deluxe', 0.5184705978674423),
#  ('Super Bomberman R', 0.5402702209328699),
#  ('Captain Toad: Treasure Tracker', 0.5404052944165109),
#  ('Cuphead', 0.5467261881037788),
#  ("Luigi's Mansion 3", 0.5473285756613352),
#  ("The Legend of Zelda: Link's Awakening", 0.5495331880577404),
#  ('Celeste', 0.5518643494673756),
#  ('Golf Story', 0.557099729229908),
#  ('Kirby and the Forgotten Land', 0.5615773105863908),
#  ('Sonic Mania Plus', 0.5616429609731847),
#  ("Yoshi's Crafted World", 0.5749193506423749),
#  ('The Messenger', 0.5800000000000001),
#  ('Katamari Damacy REROLL', 0.5963039620647383),
#  ('Overcooked!: Special Edition', 0.6009993757800316),
#  ('SteamWorld Dig 2', 0.6060397012554656),
#  ('Ori and the Blind Forest: Definitive Edition', 0.6109870529176161),
#  ('Cadence of Hyrule: Crypt of the NecroDancer Featuring The Legend of Zelda',
#   0.6115417426109394),
#  ('Axiom Verge', 0.6139410298049854),
#  ('Sonic Mania', 0.6139410298049854),
#  ('Undertale', 0.6149846624323676),
#  ('Blaster Master Zero', 0.6174350127074324),
#  ('Metroid Dread', 0.6229823813423956),
#  ('Blaster Master Zero II', 0.6302409288875127),
#  ('Cave Story +', 0.6338465086573187),
#  ('Dragon Quest', 0.6372574275573791),
#  ('Travis Strikes Again: No More Heroes', 0.6386298349093001),
#  ('WarioWare: Get It Together!', 0.640119039184329),
#  ('Snipperclips - Cut it out, together!', 0.640119039184329),
#  ('Streets of Rage 4', 0.6402380615040001),
#  ('River City Girls', 0.642140130857092),
#  ('Mega Man 11', 0.6448076704197234),
#  ('Kirby Star Allies', 0.6542833253669418),
#  ('Shantae: Half-Genie Hero', 0.6551023330572779),
#  ('Snake Pass', 0.6683317338436964),
#  ('Mighty Gunvolt Burst', 0.6736704184073077),
#  ('Cat Quest', 0.6766413177577247),
#  ("Wonder Boy: The Dragon's Trap", 0.6814193099768124),
#  ('Blossom Tales: The Sleeping King', 0.6886506625215557),
#  ('Sonic Forces', 0.6956003573022959),
#  ('Untitled Goose Game', 0.7198369420718002),
#  ('Bloodstained: Curse of the Moon', 0.7200000000000001),
#  ('Katana ZERO', 0.7302150289046075),
#  ('Kamiko', 0.7459386872308374),
#  ('Deltarune: Chapter 1', 0.7677293009927931),
#  ('Pokemon HOME', 0.7860020283954796),
#  ('GRIS', 0.8269371937952195),
#  ('1-2-Switch', 0.8547511554864493)]

# %%
out = []
for key,item in dist_dic.items():
    li = [key]

    # append first 20th games
    for i in range(len(item)):
        if (len(li) == 11):
            break
        if (item[i][0] != key):
            li.append(item[i][0])

    out.append(li)
df_recommend = pd.DataFrame(out, columns = ['game_name']+ ['recommend'+ str(i) for i in range(1,11)])
df_recommend.to_csv('content_based_rmd.csv',encoding='utf-8', index=False)
